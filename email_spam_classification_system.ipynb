# %% [markdown]
# # Import necessary functions from utils.py

# %%
from utils import load_datasets, visualize_data, preprocess_text, generate_word_cloud, split_data, train_logistic_regression, evaluate_model

# %% [markdown]
# # Load the datasets

# %%
df = load_datasets()

# %% [markdown]
# # Visualize the data

# %%
visualize_data(df)

# %% [markdown]
# # Pre-process the text data

# %%
df = preprocess_text(df)

# %% [markdown]
# # Generate Word Cloud for Spam Emails

# %%
generate_word_cloud(df)

# %% [markdown]
# # Split the dataset into train and test

# %%
train_X, test_X, train_y, test_y = split_data(df)

# %% [markdown]
# # Train a Logistic Regression model with TF-IDF vectorization

# %%
best_model = train_logistic_regression(train_X, train_y)
# Out:
# Fitting 25 folds for each of 9 candidates, totalling 225 fits
# Best Parameters:  {'clf__C': 1.0, 'tfidf__max_features': 10000}
# Best Accuracy:  0.9661137954660397

# %% [markdown]
# # Evaluate the model and display results

# %%
evaluate_model(best_model, test_X, test_y)
# Out:
# Test Accuracy with Best Model:  0.9633283294016728
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.97      0.97      0.97      2825
#      Class 1       0.95      0.96      0.95      1838
#
#     accuracy                           0.96      4663
#    macro avg       0.96      0.96      0.96      4663
# weighted avg       0.96      0.96      0.96      4663
